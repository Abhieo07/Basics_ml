# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhieo07/Basics_ml/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Natural Language Processing
#
# deals with how computers understand and process natural or human language.
#
# **Recurrent Neural Network**
# capabale of processing sequential data such as text or characters.
#
#
#
# *   Sentiment Analysis
# *   Character Generation

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Bag of words is not a very good technique to use.
#
# Example:
#
# Text 1
#
#     I thought the movie was bad but it was amazing actually!
#
# Text 2
#
#     I thought the movie was amazing but it was bad actually!

# %%
vocab = {} # maps word to integer representing it
word_encoding = 1
def bag_of_words(text):
  global word_encoding

  words = text.lower().split(" ")
  bag = {}

  for word in words:
    if word in vocab:
      encoding = vocab[word]
    else:
      vocab[word] = word_encoding
      encoding = word_encoding
      word_encoding += 1

    if encoding in bag:
      bag[encoding] += 1
    else:
      bag[encoding] = 1

  return bag

text = "This is a test to see if this test will work is is test a a"
bag = bag_of_words(text)
print(bag)
print(vocab)
# Out:
# {1: 2, 2: 3, 3: 3, 4: 3, 5: 1, 6: 1, 7: 1, 8: 1, 9: 1}
# {'this': 1, 'is': 2, 'a': 3, 'test': 4, 'to': 5, 'see': 6, 'if': 7, 'will': 8, 'work': 9}

# %% [markdown]
# **Word Embeddings**
#
# a vectorized representation of words in a given document that places words with similar meanings near each other.vbvbbb

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# RNN
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-09-06 010419.png](data:image/png;base64,...)
